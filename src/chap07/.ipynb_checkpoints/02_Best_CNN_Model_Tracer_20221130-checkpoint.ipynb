# %%
from tensorflow import keras

model = keras.models.load_model('best-cnn-model.h5')

# %%
model.layers
# Out:
# [<keras.layers.convolutional.conv2d.Conv2D at 0x1c02301ff08>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c02301fe08>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c023008508>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c0230080c8>,
#  <keras.layers.reshaping.flatten.Flatten at 0x1c023010588>,
#  <keras.layers.core.dense.Dense at 0x1c022fe4348>,
#  <keras.layers.regularization.dropout.Dropout at 0x1c023000348>,
#  <keras.layers.core.dense.Dense at 0x1c022ff2908>]

# %%
conv = model.layers[0]
print(conv.weights[0].shape, conv.weights[1].shape)
# Out:
# (3, 3, 1, 32) (32,)

# %%
import numpy

conv_weights = conv.weights[0].numpy()
print(conv_weights.mean(), conv_weights.std())
# Out:
# -0.039864466 0.3013197

# %%
import matplotlib.pyplot as plt
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

plt.hist(conv_weights.reshape(-1,1))
plt.xlabel('weight')
plt.ylabel('count')
plt.show()

# %%
fig, axs = plt.subplots(2,16, figsize=(15,2)) # figsize인치

for i in range(2):
    for j in range(16):
        axs[i,j].imshow(conv_weights[:,:,0, i * 16 + j], vmin=-0.5, vmax=0.5)
        axs[i,j].axis('off')
        
plt.show()

# %%
no_training_model = keras.Sequential()
no_training_model.add(keras.layers.Conv2D(filters=32, kernel_size=(3,3), input_shape=(28,28,1), padding='same',
                             activation='relu'))

# %%
no_training_conv = no_training_model.layers[0]
print(no_training_conv.weights[0].shape)
# Out:
# (3, 3, 1, 32)

# %%
no_training_weights = no_training_conv.weights[0].numpy()
print(no_training_weights.mean(), no_training_weights.std())
# Out:
# -0.0005667812 0.08153395

# %%
plt.hist(no_training_weights.reshape(-1,1))
plt.xlabel('weight')
plt.ylabel('count')
plt.show()

# %%
fig, axs = plt.subplots(2,16, figsize=(15,2)) # figsize인치

for i in range(2):
    for j in range(16):
        axs[i,j].imshow(no_training_weights[:,:,0, i * 16 + j], vmin=-0.5, vmax=0.5)
        axs[i,j].axis('off')
        
plt.show()
