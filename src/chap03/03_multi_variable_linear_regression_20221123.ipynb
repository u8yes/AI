# %%
import tensorflow as tf
import numpy as np

# %%
x_data = [
          [73.,80.,75.],
          [93.,88.,93.],
          [89.,91,90.],
          [96.,98.,100.],
          [73.,66.,70.]
          ]

y_data = [
          [152],
          [185],
          [180],
          [196],
          [142]
         ]

# %%
tf.model = tf.keras.Sequential()

tf.model.add(tf.keras.layers.Dense(input_dim=3, units=1)) # input_dim=3는 feature 수를 얘기하기 때문에 차원으로 오해하지 말자.
tf.model.add(tf.keras.layers.Activation('linear'))

# %%
tf.model.compile(loss='mse',optimizer=tf.keras.optimizers.SGD(learning_rate=1e-5))
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 4
#
#  activation (Activation)     (None, 1)                 0
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss = tf.model.fit(x_data, y_data, epochs=100) # 'inf'inity
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 313ms/step - loss: 4732.3491
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1484.1169
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 465.9681
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 146.8323
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 46.8001
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 15.4447
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6162
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.5351
# Epoch 9/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5690
# Epoch 10/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2658
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1704
# Epoch 12/100
# ...

# %%
x_predict = tf.model.predict(np.array([[72.,93.,90.]]))
x_predict
# Out:
# 1/1 [==============================] - 0s 68ms/step
# array([[159.09761]], dtype=float32)
