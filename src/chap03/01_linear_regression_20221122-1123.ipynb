# %% [markdown]
# # 신경망 구현 순서
# 1. Sequential 모형 클래스 객체 생성
# 2. add 메서드로 레이어 추가.
#   - 입력단부터 순차적으로 추가한다.
#   - 레이어는 출력 뉴런 갯수를 첫번째 인수로 받는다.
#   - 최초의 레이어는 input_dim 인수로 입력 크기를 설정해야 한다.
#   - activation 인수로 활성화 함수 설정
# 3. compile 메서드로 모형 완성.
#   - loss인수로 비용함수 설정
#   - optimizer 인수로 최적화 알고리즘 설정
#   - metrics 인수로 트레이닝 단계에서 기록할 성능 기준 설정
# 4. fit 메서드로 트레이닝
#   - epochs로 에포크(epoch) 횟수 설정

# %%
# 텐서플로우 설치(command 창에서)
# conda install tensorflow

# 텐서플로우 설치 확인
import tensorflow as tf # 사이킷런은 딥러닝 지원 안 됨.
import numpy as np

print(tf.__version__) # 2.9.1버전부터는 keras로직에 접근가능해졌음.
# Out:
# 2.9.1

# %%
# 가설 설정은 H(x) = w(기울기)x + b(절편)
x_train = [1,2,3,4] # 하나의 특성은 단순회귀분석이다.
y_train = [0,-1,-2,-3] # w는 -1, b는 1

# %%
tf.model = tf.keras.Sequential() # 모델 생성하기 위해서 Sequential 자료형을 통해서 모형을 만들 객체 생성.
# 회귀분석을 할 건지 어떤 알고리즘을 할 건지 tf.model에 변수로 저장해놓고 보려하는 것임. only 틀을 만들어줌.

# %%
# input_dim : input shape, units : output shape
tf.model.add(tf.keras.layers.Dense(input_dim=1, units=1)) # 꾸미는 작업을 add # 1차원 단층 회귀
# 마치 생성자 함수처럼 정의 돼있음. # input_dim은 입력 차원으로 알려주면 됨. # units은 출력 차원

# %%
# SGD(Stochastic Gradient Descendent) - 확률적 경사하강법, lr(learning_rate) - 이동의 간격을 지정해줌.
# 미분해서 0이 되는 값을 찾겠다는 것.
sgd = tf.keras.optimizers.SGD(lr=0.1) # learning_rate * 기울기 
# 기본적으로는 lr=0.1의 값으로 시작. 이 간격으로 옮겨가겠다는 것.
# 변수로 넣는 것은 또 다른 알고리즘이 있기 때문이다. 하나밖에 없었으면 변수로 안 만들고 작업했을 것이다.
# Out:
# C:\ProgramData\Anaconda3\envs\tf_cpu\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
# 목표는 Minimize cost이다.
# mse(mean_squared_error) - 잔차를 제곱해서 평균을 내라, 1/m * sig(y' - y) ^ 2 
# 접선의 기울기를 미분하면서 최적으로 학습하면서 접선의 기울기가 0으로 되는 최적의 W값을 찾아감

tf.model.compile(loss='mse', optimizer='sgd')  
# mean square error = cost function을 적용하라. # optimizer='sgd' 인수로 최적화 알고리즘 설정

# %%
# 학습 전, 최초 설정된 w 값 조화
weights = tf.model.layers[0].get_weights()
w = weights[0][0][0] # 면 행 열로 접근해서 w값을 꺼낼 수 있다.
print('initial w is : ' + str(w)) # 랜덤으로 w값을 잡음.
# Out:
# initial w is : 1.433211

# %%
tf.model.summary() # 신경망을 어떻게 구성해주고 있는지 알려줌. # Output Shape (None, 1) 피처는 1개
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.model.fit(x_train, y_train, epochs=200) 
# 대표적인 지도학습 # epochs=200 번 반복하면서 학습하라고 명령 # 너무 적으면 과소적합 # loss(cost)값을 찾음.
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 2/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 3/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 4/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 5/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 6/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 7/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 8/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 9/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 10/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 11/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 12/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 13/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 14/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 15/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 16/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 17/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 18/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 19/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 20/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 21/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 22/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 23/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 24/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 25/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1587e-04
# Epoch 154/200
# 1/1 [==============================] - 0s 5ms/step - loss: 8.1099e-04
# Epoch 155/200
# 1/1 [==============================] - 0s 3ms/step - loss: 8.0615e-04
# Epoch 156/200
# 1/1 [==============================] - 0s 4ms/step - loss: 8.0132e-04
# Epoch 157/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.9653e-04
# Epoch 158/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.9177e-04
# Epoch 159/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.8704e-04
# Epoch 160/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.8233e-04
# Epoch 161/200
# 1/1 [==============================] - 0s 5ms/step - loss: 7.7765e-04
# Epoch 162/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.7301e-04
# Epoch 163/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.6839e-04
# Epoch 164/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.6379e-04
# Epoch 165/200
# 1/1 [==============================] - 0s 5ms/step - loss: 7.5922e-04
# Epoch 166/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.5468e-04
# Epoch 167/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.5017e-04
# Epoch 168/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4569e-04
# Epoch 169/200
# 1/1 [==============================] - 0s 5ms/step - loss: 7.4123e-04
# Epoch 170/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.3680e-04
# Epoch 171/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.3239e-04
# Epoch 172/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2802e-04
# Epoch 173/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2366e-04
# Epoch 174/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.1934e-04
# Epoch 175/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1503e-04
# Epoch 176/200
# 1/1 [==============================] - 0s 5ms/step - loss: 7.1076e-04
# Epoch 177/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.0651e-04
# Epoch 178/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0229e-04
# Epoch 179/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9809e-04
# Epoch 180/200
# 1/1 [==============================] - 0s 5ms/step - loss: 6.9391e-04
# Epoch 181/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8977e-04
# Epoch 182/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.8564e-04
# Epoch 183/200
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8154e-04
# Epoch 184/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.7747e-04
# Epoch 185/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.7342e-04
# Epoch 186/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6939e-04
# Epoch 187/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6539e-04
# Epoch 188/200
# 1/1 [==============================] - 0s 5ms/step - loss: 6.6141e-04
# Epoch 189/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.5746e-04
# Epoch 190/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.5352e-04
# Epoch 191/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.4962e-04
# Epoch 192/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.4573e-04
# Epoch 193/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.4188e-04
# Epoch 194/200
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3804e-04
# Epoch 195/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3422e-04
# Epoch 196/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.3043e-04
# Epoch 197/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.2666e-04
# Epoch 198/200
# 1/1 [==============================] - 0s 5ms/step - loss: 6.2291e-04
# Epoch 199/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.1919e-04
# Epoch 200/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.1549e-04

# %%
y_predict = tf.model.predict(np.array([5])) # 넘파이 이용해서 5를 예측해봄 # 결과는 -4에 가까움
y_predict
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[-3.9575956]], dtype=float32)

# %%
# 학습을 통해 구한 w(기울기)와 b(절편, 편향)의 값
tf.model.layers[0].get_weights() # w = -1, b = 1
# Out:
# [array([[-0.97941417]], dtype=float32), array([0.93947524], dtype=float32)]
